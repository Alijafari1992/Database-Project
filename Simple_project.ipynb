# %% [markdown]
# <a href="https://colab.research.google.com/github/Alijafari1992/Database-Project/blob/main/Simple_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas==1.3.3
# # !pip install requests==2.26.0
# # !mamba install bs4==4.10.0 -y
# # !mamba install html5lib==1.1 -y
# # !pip install lxml==4.6.4
# # !pip install plotly==5.3.1
import pandas as pd
import numpy as np

# %%
d={'Mouse':[150,200,300,400],'Keyboard':[180,200,190,300],'Scanner':[200,280,330,450]}
d
# Out:
# {'Mouse': [150, 200, 300, 400],
#  'Keyboard': [180, 200, 190, 300],
#  'Scanner': [200, 280, 330, 450]}

# %%
df=pd.DataFrame(d,index=['Jan','Feb','March','April'])
df
# Out:
#        Mouse  Keyboard  Scanner
# Jan      150       180      200
# Feb      200       200      280
# March    300       190      330
# April    400       300      450

# %%
d={'Mouse':[150,200,300,400],'Keyboard':[180,200,190,300],'Scanner':[200,280,330,450]}
#d={'Mouse':[150,200,300,400],'Scanner':[200,280,330,450]}

# %% [markdown]
# **Which of the following is the correct syntax to select or access columns from the dataframe using column names?**

# %%
df[['Mouse','Keyboard','Scanner']]
df
# Out:
#        Mouse  Keyboard  Scanner
# Jan      150       180      200
# Feb      200       200      280
# March    300       190      330
# April    400       300      450

# %% [markdown]
# **Just print one columns**

# %%
df['Mouse']
# Out:
# Jan      150
# Feb      200
# March    300
# April    400
# Name: Mouse, dtype: int64

# %%
df=pd.DataFrame(d)

# %% [markdown]
#  Write code to access data of all columns where mouse data is
# more than 200 **bold text**. **bold text**

# %%
#iloc is primarily an integer based indexing counting from 0. That is, your specify rows and columns giving a numbe
dat=df[df.iloc[:,0:4]>200]
dat
# Out:
#    Mouse  Keyboard  Scanner
# 0    NaN       NaN      NaN
# 1    NaN       NaN    280.0
# 2  300.0       NaN    330.0
# 3  400.0     300.0    450.0

# %% [markdown]
# **Write code to access columns using 0 and 2.**

# %%
df[0:2]
# Out:
#    Mouse  Keyboard  Scanner
# 0    150       180      200
# 1    200       200      280

# %% [markdown]
# **Write code to access data of rows of jan and march for scanner**
# **and keyboard** **bold text**

# %%
#df=pd.DataFrame(d,index=['Jan','','March',''])
df=pd.DataFrame(d,index=['Jan','','March',''])
df
# Out:
#        Mouse  Keyboard  Scanner
# Jan      150       180      200
#          200       200      280
# March    300       190      330
#          400       300      450

# %%
df.keys()
# Out:
# Index(['Mouse', 'Keyboard', 'Scanner'], dtype='object')

# %%
df.values
# Out:
# array([[150, 180, 200],
#        [200, 200, 280],
#        [300, 190, 330],
#        [400, 300, 450]])

# %%
df.Keyboard
# Out:
# Jan      180
#          200
# March    190
#          300
# Name: Keyboard, dtype: int64

# %%
df.dtypes
# Out:
# Mouse       int64
# Keyboard    int64
# Scanner     int64
# dtype: object

# %%
df.describe()
# Out:
#             Mouse    Keyboard     Scanner
# count    4.000000    4.000000    4.000000
# mean   262.500000  217.500000  315.000000
# std    110.867789   55.602758  104.721854
# min    150.000000  180.000000  200.000000
# 25%    187.500000  187.500000  260.000000
# 50%    250.000000  195.000000  305.000000
# 75%    325.000000  225.000000  360.000000
# max    400.000000  300.000000  450.000000

# %%
# # Selecting rows and columns
# print(df.loc['Mouse', 'Scanner'])

# %%
df.iloc[0:5]
# Out:
#        Mouse  Keyboard  Scanner
# Jan      150       180      200
#          200       200      280
# March    300       190      330
#          400       300      450
